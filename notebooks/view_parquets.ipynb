# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/ai-projects/forecast-studio
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/ai-projects/forecast-studio

# %%
import pandas as pd

df = pd.read_parquet("train_features.parquet")

print(df.shape)
print(df.head())
# Out:
# (716500, 15)
#         date series_id  store  item  sales  dow  is_weekend  weekofyear  \
# 0 2013-01-29      10_1     10     1     14    1           0           5
# 1 2013-01-30      10_1     10     1     17    2           0           5
# 2 2013-01-31      10_1     10     1      5    3           0           5
# 3 2013-02-01      10_1     10     1     21    4           0           5
# 4 2013-02-02      10_1     10     1     11    5           1           5
#
#    lag_1  lag_7  lag_28  roll_mean_7  roll_mean_28  roll_std_7  roll_std_28
# 0   12.0    7.0    14.0    14.857143     14.678571    3.933979     3.887812
# 1   14.0   20.0    14.0    14.428571     14.785714    3.408672     3.909695
# 2   17.0   12.0    16.0    13.428571     14.392857    4.928054     4.314826
# 3    5.0   21.0    17.0    13.428571     14.535714    4.928054     4.467845
# 4   21.0   13.0    12.0    13.142857     14.500000    5.014265     4.492793

# %%
df = pd.read_parquet("test_features.parquet")

print(df.shape)
print(df.head())
# Out:
# (14000, 15)
#         date series_id  store  item  sales  dow  is_weekend  weekofyear  \
# 0 2017-01-01      10_1     10     1     25    6           1          52
# 1 2017-01-02      10_1     10     1     11    0           0           1
# 2 2017-01-03      10_1     10     1     16    1           0           1
# 3 2017-01-04      10_1     10     1     17    2           0           1
# 4 2017-01-05      10_1     10     1     28    3           0           1
#
#    lag_1  lag_7  lag_28  roll_mean_7  roll_mean_28  roll_std_7  roll_std_28
# 0   28.0   30.0    23.0    22.142857     20.964286    5.047394     5.301866
# 1   25.0   21.0    17.0    20.714286     20.750000    6.600866     5.581882
# 2   11.0   17.0    21.0    20.571429     20.571429    6.704654     5.653112
# 3   16.0   14.0    23.0    21.000000     20.357143    6.298148     5.671333
# 4   17.0   25.0    19.0    21.428571     20.678571    6.704654     5.843981
