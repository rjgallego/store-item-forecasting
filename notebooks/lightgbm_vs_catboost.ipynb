# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/ai-projects/forecast-studio
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/ai-projects/forecast-studio

# %%
import json
from pathlib import Path

import pandas as pd

base_metrics = "reports/baseline_metrics.json"
cat_metrics = "reports/catboost_metrics.json"

baseline = pd.read_json(base_metrics, typ="series")
catboost = pd.read_json(cat_metrics, typ="series")

pd.DataFrame({
    "metric": baseline.index,
    "basline": baseline.values,
    "catboost": [catboost.get(m, None) for m in baseline.index]
})
# Out:
#               metric     basline   catboost
# 0                mae    4.122625   4.096743
# 1               rmse    5.335292   5.303736
# 2          naive_mae    8.539714   8.539714
# 3         naive_rmse   11.438981  11.438981
# 4         num_series  500.000000        NaN
# 5    mean_series_mae    4.122625   4.096743
# 6  median_series_mae    3.913112   3.914562
